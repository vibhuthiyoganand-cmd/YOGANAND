# %%
age = 30

if age >=18:
    print("you can votel")
    print("voting is on may 31st")
    print("see you at polling station")
else:
  print("wait for", 18-age, "year.")
print("BYE!!!")
# Out:
# you can votel
# voting is on may 31st
# see you at polling station
# BYE!!!

# %%
age = 16

if age >=18:
    print("you can votel")
    print("voting is on may 31st")
    print("see you at polling station")
else:
  print("wait for", 18-age, "year")
print("BYE!!!")
# Out:
# wait for 2 year
# BYE!!!

# %%
+32
# Out:
# Grade A

# %%
marks = 88

if marks >=90:
      print("Grade A")
elif marks >=80:
     print("Grade B")
elif marks >=70:
     print("Grade C")
elif marks >=60:
     print("Grade D")
elif marks >=50:
     print("Grade E")

# jumps here
# Out:
# Grade B

# %%
marks = 44

if marks >=90:
    print("Grade A")
elif marks >=80:
     print("Grade B")
elif marks >=70:
     print("Grade C")
elif marks >=60:
     print("Grade D")
elif marks >=50:
     print("Grade E")
else:
    print("false")

# jumps here
# Out:
# false

# %%
marks = -5

if marks >=90:
    print("Grade A")
elif marks >=80:
     print("Grade B")
elif marks >=70:
     print("Grade C")
elif marks >=60:
     print("Grade D")
elif marks >=50:
     print("Grade E")
else:
    print("false")
# Out:
# false

# %%
marks = 105

if marks >=90 and marks <=100:
    print("Grade A")
elif marks >=80 and marks <=90:
     print("Grade B")
elif marks >=70 and marks <=80:
     print("Grade C")
elif marks >=60 and marks <=70:
     print("Grade D")
elif marks >=50 and marks <=60:
     print("Grade E")
elif marks >=0 and marks <50:
    print("false")

else:
    print("not a valid entry")


    # jump here
# Out:
# not a valid entry

# %%
marks = -5

if marks >=90 and marks <=100:
    print("Grade A")
elif marks >=80 and marks <=90:
     print("Grade B")
elif marks >=70 and marks <=80:
     print("Grade C")
elif marks >=60 and marks <=70:
     print("Grade D")
elif marks >=50 and marks <=60:
     print("Grade E")
elif marks >=0 and marks <50:
    print("false")

else:
    print("not a valid entry")


    # jump here
# Out:
# not a valid entry

# %%
# nested ifs -one inside another
EXP = 3
EDU = 'mba'

input_exp = int (input("enter your experience:"))
input_exp = input("Enter your education:")


if input_exp >= EXP and input_edu == EDU:
      print("can apply for the job.")
elif:input_exp >= EXP and input_edu != EDU:
             print("education is not sufficient")
elif input_exp >= EXP and input_edu != EDU:
    print("not sufficient experience")
else:
    print("you don't meet educational qualification and experience")
# Out:
#   Cell In[48], line 11
#     elif:input_exp >= EXP and input_edu != EDU:
#         ^
# SyntaxError: invalid syntax
