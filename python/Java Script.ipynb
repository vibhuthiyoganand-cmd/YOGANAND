# %% [markdown]
# #### Definition:
#
# - JavaScript is a high-level, interpreted scripting language used to create dynamic and interactive content on websites.
#
# #### Purpose:
#
# - It adds functionality to web pages - like responding to user actions, validating forms, updating content without refreshing the page, etc.
#
#
#
# #### Where is it used?
#
# - Frontend (with HTML & CSS)
# - Backend (using Node.js)
# - Mobile apps
# - Game development
# - Serverless functions

# %% [markdown]
#    #### syntax

# %% [markdown]
# - syntax means the set of rules that defines how javascript code should be written and structured.
# - if you don't follow proper syntax the code won't run- just like grammer in a language

# %% [markdown]
# #### Console.log(), Document.write()& Document.getElementByld()

# %% [markdown]
#  **console.log()**
#   - Is mainly used for debugging
#   - it display message only in the browser console(not visible to users).
#   - Developer use it to test value and track errors

# %%
who we will use it
console.log("hello world");

# %% [markdown]
#  **Document.write()**
#   -  write content directly onto the webpage
#   - it is simplae, but if ud=sed after page load, it can overwrite the whole page
#   - not recommended for modern wed development.

# %%
who we will use it
document.write("hello world");

# %% [markdown]
#  **Document.getElementByID()**

# %% [markdown]
# -  Is used to access an element by its unique ID
# -  We can read or change the concet of the element.
# -  Example: documengt.getElementByld("demo").innerHTML = "HELLO";
# -  It is the preferred way to dynamically update wedpage content

# %%
who we will use it
<p id= "class">hello world</p> 
<script> 
    decoument.grt ElementByID("Class").innerhtml="hello"
</script>

# %% [markdown]
# #### Java Script Setup

# %%
Way to add JS:
1. Imline JS
2. Internal JS(inside<script>tags)
3. External JS (linking.js files).

# %%
Example:
<script src='app.js'><script>

# %% [markdown]
# ***Inline java Script***
# - java script code is written directly inside an HTML tag.
# - Usually used with event attributes like onclick, onmouseover, etc.
# - Suitable for very small task button click or alerts.
# - Keeps HTML ans JS mixed in the same line.
# - Not recommended for lager project.
