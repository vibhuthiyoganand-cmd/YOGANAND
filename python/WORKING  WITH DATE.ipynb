# %% [markdown]
# # WORKING WITH DATES

# %% [markdown]
# - these are not date and time value:
# ```
# '2026-06-25'
# "25/06/2026"
# "2026/6/25"
# "10:30"

# %% [markdown]
# - To work with date,time and datetime value import the `datetime` module
# - The `datetime`  module contians three contructors to work with date, time, and datetime, and the constructors are `date`, `time` and `datetime`.
# - The `date` contructor is used to construct date value
# - The `time` contructor is used to construct time value
# - tHE `datetime` contructor is used ti construct datetime value

# %%
# import the constructors
from datetime import date
from datetime import time
from datetime import datetime

# %%
# you can run the three statement in one go
from datetime import date, time, datetime

# %% [markdown]
# ## Working with `date` constructor
