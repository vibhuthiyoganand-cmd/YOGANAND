# %% [markdown]
# # Tuples

# %% [markdown]
# - tuples is a coolesction of sequential items.
# - Tuples are immutable
# - Every item has an index numder similar to list object items. Both postive index number and negative index number.

# %% [markdown]
# - *syntax*
# ```
#
# (item 1, item2, item3, item4,...)

# %%
week_days = ('sun', 'mon', 'tue', 'wed', 'thu', 'fri', 'sat')

# %%
# week_days.append('sunday')  $ throws an error (exception)

# %%
week_days[0]
# Out:
# 'sun'

# %%
week_days[5]
# Out:
# 'fri'

# %%
week_days[3]
# Out:
# 'wed'

# %%
week_days[-6]
# Out:
# 'mon'

# %%
# week_days[0] -'Sunday'

# %%
# unpacking a tuple
d1,d2,d3,d4,d5,d6,d7 = week_days

# %%
d1
# Out:
# 'sun'

# %%
d2
# Out:
# 'mon'

# %%
d3
# Out:
# 'tue'

# %%
d4
# Out:
# 'wed'

# %%
d5
# Out:
# 'thu'

# %%
d6
# Out:
# 'fri'

# %%
d7
# Out:
# 'sat'

# %%
joined_items = ('jan', 'fed', 'mar') + ('apr',  'may', 'jun')
joined_items
# Out:
# ('jan', 'fed', 'mar', 'apr', 'may', 'jun')
