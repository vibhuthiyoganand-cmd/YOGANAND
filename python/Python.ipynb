# %% [markdown]
# ## Introduction to the python

# %% [markdown]
# →  **Introduction to the python programming**

# %% [markdown]
# - prgramming is now has a set of instrution
# - Instrution is now has set of rules or command

# %% [markdown]
# *software is a set of programm operating system*

# %% [markdown]
# 1. window
# 2. mac
# 3. unix

# %% [markdown]
# → **python is interpreted language and python is also now has interperted based language**

# %% [markdown]
# → **python support oops**

# %% [markdown]
# 1. class
# 2. objects
# 3. inheritance
# 4. paymophism
# 5. obstraction
# 6. enaperation

# %% [markdown]
# → **python is easy to learn and easy to understand**

# %% [markdown]
# - Introduction
#   - python user
# - Operators
#    - Arithmetics
#    - comparison
#    - logical

# %% [markdown]
# ## Introduction to 'python'
# - easy to learn(plain english)
# - General purpose language
#     - Scripting language
#     - programming language
# - It has a lager community
# - Third-praty librariss (pypI - pypi.org)

# %% [markdown]
# ## Data types (primitive)

# %% [markdown]
# - Integers
# - Float
# - String
# - Booleans

# %% [markdown]
# ### Integers

# %% [markdown]
# - An number without decimal point (fractional part) is an integer
# - -55 , -10 , 100 , 20 ,0 , 17

# %%
300
# Out:
# 300

# %%
-48
# Out:
# -48

# %%
0
# Out:
# 0

# %% [markdown]
# ### Float - point number (float)

# %% [markdown]
# - An number with a fractional part ( decimal point )
# - 4.3, -1.7, 12.15, 100.001, -7.89, 0.0, 5.0, 7.0

# %%
-5.001
# Out:
# -5.001

# %%
10.0
# Out:
# 10.0

# %%
100.1 + 100.1 + 100.1
# Out:
# 300.29999999999995

# %% [markdown]
# ### String (text)

# %% [markdown]
# - To specify a string (text), surround it with quotes (single or double)
#     -  'Hello'   # text --- MSSQL sever uses single quotes
#     -   "goodbye"   #text
# -   Dont use quotes inconsistently:
#     - " goodbye' #error
#     - 'hello"  #error
# - Iy you dont use quotes: then its is not a text
# - Use triple quotes ('''text''' or """text""") for mutiple text
#        - Multline text is not a comment

# %%
'Hello world!'
# Out:
# 'Hello world!'

# %%
"goodbye"
# Out:
# 'goodbye'

# %%
''' This is line one.
this is line two.
this is line three.'''
# Out:
# ' This is line one.\nthis is line two.\nthis is line three.'

# %% [markdown]
# ### Boolean value

# %% [markdown]
# - true and false are Boolean values
# - We use boolean value to make decision
# - We validate propositions
# - To control the flow and program

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
None # not a boolean value

# %% [markdown]
# ## Operators
# - Arithmetic operators
# - Comparison operators (Boolean operators)
# - Logical operators (Boolean operator
# - Text operators

# %% [markdown]
# ### Arithetic operator
# - +(addition)
# - -(subraction)
# - *(mutiplication)
# - /(division)
# - //(inetger/floor division)
# - %(modulus/remainder)
# - **(exponemt/power

# %%
100+50
# Out:
# 150

# %%
100 - 50
# Out:
# 50

# %%
100 * 50
# Out:
# 5000

# %%
100 / 50
# Out:
# 2.0

# %%
# division
27 / 4
# Out:
# 6.75

# %%
# for quotient use integer divison / fllor division
27 // 4
# Out:
# 6

# %%
# remainder (modules)
27 % 4
# Out:
# 3

# %%
# exponent (power)
2**5
# Out:
# 32

# %%
2**1000
# Out:
# 

# %% [markdown]
# ### Comparison operator (part of boolean operator)
# - we compare/relate value (data)
# - comparison operator
# - == (equal to)
# - !=(not equal to)
# - > (greater than)
# - < (less than)
# - >= (greater than or equal to)
# - <=(lessthan or equal to)
# - comparing two values return Ture or False (Boolean result)

# %%
500 == 500
# Out:
# True

# %%
500 == 260
# Out:
# False

# %%
100 != 100
# Out:
# False

# %%
19 < 199
# Out:
# True

# %%
'A' > 'a'
# Out:
# False

# %%
'a' > 'A'
# Out:
# True

# %%
 chr(3077)
# Out:
# 'అ'

# %%
chr(3078)
# Out:
# 'ఆ'

# %%
chr(3079)
# Out:
# 'ఇ'

# %%
chr(3080)
# Out:
# 'ఈ'

# %% [markdown]
# ### Logical operator (return Boolean values)
# - not
# - and
# - or
# - Used to create a Boolean expression which returns a Boolean vale
# - It comdines boolean experssions

# %% [markdown]
# #### Not operator
# - Negation operator ( reverses the outcomes of a Boolean experssion)
# - not ture -> fales
# - not false -> ture

# %%
True
# Out:
# True

# %%
not True
# Out:
# False

# %%
False
# Out:
# False

# %%
not False
# Out:
# True

# %%
not 100>50
# Out:
# False

# %%
not 50<100
# Out:
# False

# %%
 not 500==500
# Out:
# False

# %% [markdown]
# #### And operator
# - Combines two Boolean experssion returning to Boolean value
# - syntax
# - bool_exp1 and bool_exp2
# - reture true only when booth boolean experssion are true; otherwise returns false

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
1==1 and 2==2
# Out:
# True

# %%
1 !=1 and 2==2
# Out:
# False

# %%
1!=1 and 2 !=2
# Out:
# False

# %% [markdown]
# ###  or operator
# - used to comdine boolean experssion
# - syntax
# - bool_exp1 or bool exp2
# - reture true if at least one boolean experssion is true; otherwise

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %% [markdown]
# ###  string operators
# - concatenation(text joining)operator-+
# - repeation operation-*
